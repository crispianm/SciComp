# %% [markdown]
# ## Week 4 Q1

# %%
include("../ode_solver.jl")
using PlotlyJS
using NLsolve
# Out:
# WebIO._IJuliaInit()

# %%
function predprey(u, t)

    # println(u)

    if(!isapprox(length(u), 2.0; atol=eps(Float64), rtol=0))
        throw(error("Please make sure you have entered two initial conditions for the function."))
    end

    a = 1
    b = 0.2
    d = 0.1
    x = u[1]    
    y = u[2]
    
    x_dot = x.*(1-x) - (a.*x.*y)./(d + x)
    y_dot = b.*y.*(1 - (y./x))
    
    return [x_dot y_dot]
end

t = 0:0.1:500
u0 = [.5 .25]
# u0 = [1 1]


include("../visualisation.jl")

plot_ode(predprey, u0, t, ["x" "y"])
# Out:
# data: [
#   "scatter with fields mode, name, showlegend, type, x, and y",
#   "scatter with fields mode, name, showlegend, type, x, and y"
# ]
#
# layout: "layout with fields height, margin, template, width, and xaxis"

# %% [markdown]
# Isolate a periodic orbit: a = 1, b = 0.25, d = 0.1
#
# What are its starting conditions?
# [.5 .25]
#
# What is its period?:
# Roughly 20s

# %% [markdown]
# ## Week 4 Q3

# %%
include("../numerical_shooting.jl")
# Out:
# find_limit_cycle (generic function with 1 method)

# %%
u0, T = find_limit_cycle(predprey, [1; 1], [20.0])
println("u0: ", u0)
println("Period: ", T)
# Out:
# ArgumentError: number of rows of each array must match (got (2, 1))
#
# Stacktrace:
#  [1] _typed_hcat(#unused#::Type{Float64}, A::Tuple{Vector{Int64}, Vector{Float64}})
#    @ Base .\abstractarray.jl:1570
#  [2] typed_hcat
#    @ .\abstractarray.jl:1557 [inlined]
#  [3] hcat
#    @ C:\Users\crisp\AppData\Local\Programs\Julia-1.7.2\share\julia\stdlib\v1.7\SparseArrays\src\sparsevector.jl:1125 [inlined]
#  [4] find_limit_cycle(f::Function, u0::Vector{Int64}, T::Vector{Float64}; phase_index::Int64, arg::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ Main c:\Users\crisp\Desktop\Uni\SciComp\numerical_shooting.jl:67
#  [5] find_limit_cycle(f::Function, u0::Vector{Int64}, T::Vector{Float64})
#    @ Main c:\Users\crisp\Desktop\Uni\SciComp\numerical_shooting.jl:53
#  [6] top-level scope
#    @ In[14]:1
#  [7] eval
#    @ .\boot.jl:373 [inlined]
#  [8] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
# ...

# %% [markdown]
# ## Workspace

# %%
if findall(x->isa(x, Float64), [1 3.5]) != 0
    throw(error("Please make sure your input contains at least one float."))
end
# Out:
# Please make sure your input contains at least one float.
#
# Stacktrace:
#  [1] error(s::String)
#    @ Base .\error.jl:33
#  [2] top-level scope
#    @ In[12]:2
#  [3] eval
#    @ .\boot.jl:373 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
size([1 1 2 5])[1]
# size([1; 1])[1]
# Out:
# 1

# %%
include("../numerical_shooting.jl")
u0, T = find_limit_cycle(predprey, [1 1], 20)
println("u0: ", u0)
println("Period: ", T)
# Out:
# 0
# u0: [0.5778714844291404 0.2861488834698955]
# Period: 20.816866584064794
